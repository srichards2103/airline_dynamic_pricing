# %%
import pandas as pd

df = pd.read_csv('grid_search_results.csv')

# %%
df
# Out:
#        g_B  d_B   h_B  a_B    b_B  g_E  d_E   h_E   a_E    b_E  total_revenue  \
# 0      1.8   50 -0.10  0.1  0.005  4.8  150 -0.10  0.05  0.002   10009.737863
# 1      1.8   50 -0.10  0.1  0.005  4.8  150 -0.10  0.05  0.004    7544.250066
# 2      1.8   50 -0.10  0.1  0.005  4.8  150 -0.10  0.05  0.006    3083.011031
# 3      1.8   50 -0.10  0.1  0.005  4.8  150 -0.10  0.10  0.002     854.703360
# 4      1.8   50 -0.10  0.1  0.005  4.8  150 -0.10  0.10  0.004       0.018355
# ...    ...  ...   ...  ...    ...  ...  ...   ...   ...    ...            ...
# 59044  2.2   70 -0.01  0.3  0.015  5.2  170 -0.01  0.10  0.004       0.018169
# 59045  2.2   70 -0.01  0.3  0.015  5.2  170 -0.01  0.10  0.006       0.013518
# 59046  2.2   70 -0.01  0.3  0.015  5.2  170 -0.01  0.15  0.002       0.000019
# 59047  2.2   70 -0.01  0.3  0.015  5.2  170 -0.01  0.15  0.004       0.000010
# 59048  2.2   70 -0.01  0.3  0.015  5.2  170 -0.01  0.15  0.006       0.000007
#
# ...
